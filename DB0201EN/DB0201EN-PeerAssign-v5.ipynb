# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>
#
# <h1 align=center><font size = 5>Assignment: Notebook for Peer Assignment</font></h1>

# %% [markdown]
# # Introduction
#
# Using this Python notebook you will:
#
# 1.  Understand three Chicago datasets
# 2.  Load the three datasets into three tables in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Understand the datasets
#
# To complete the assignment problems in this notebook you will be using three datasets that are available on the city of Chicago's Data Portal:
#
# 1.  <a href="https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2">Socioeconomic Indicators in Chicago</a>
# 2.  <a href="https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t">Chicago Public Schools</a>
# 3.  <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2">Chicago Crime Data</a>
#
# ### 1. Socioeconomic Indicators in Chicago
#
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2](https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 2. Chicago Public Schools
#
# This dataset shows all school level performance data used to create CPS School Report Cards for the 2011-2012 school year. This dataset is provided by the city of Chicago's Data Portal.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t](https://data.cityofchicago.org/Education/Chicago-Public-Schools-Progress-Report-Cards-2011-/9xs2-f89t?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)
#
# ### 3. Chicago Crime Data
#
# This dataset reflects reported incidents of crime (with the exception of murders where data exists for each victim) that occurred in the City of Chicago from 2001 to present, minus the most recent seven days.
#
# A detailed description of this dataset and the original dataset can be obtained from the Chicago Data Portal at:
# [https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ)

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to have these three tables populated with a subset of the whole datasets.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the links below to download and save the datasets (.CSV files):
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv" target="_blank">Chicago Census Data</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoPublicSchools.csv" target="_blank">Chicago Public Schools</a>
#
# -   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv" target="_blank">Chicago Crime Data</a>
#
# **NOTE:** Ensure you have downloaded the datasets using the links above instead of directly from the Chicago Data Portal. The versions linked here are subsets of the original datasets and have some of the column names modified to be more database friendly which will make it easier to complete this assignment.

# %% [markdown]
# ### Store the datasets in database tables
#
# To analyze the data using SQL, it first needs to be stored in the database.
#
# While it is easier to read the dataset into a Pandas dataframe and then PERSIST it into the database as we saw in Week 3 Lab 3, it results in mapping to default datatypes which may not be optimal for SQL querying. For example a long textual field may map to a CLOB instead of a VARCHAR.
#
# Therefore, **it is highly recommended to manually load the table using the database console LOAD tool, as indicated in Week 2 Lab 1 Part II**. The only difference with that lab is that in Step 5 of the instructions you will need to click on create "(+) New Table" and specify the name of the table you want to create and then click "Next".
#
# <img src = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/images/LoadingData.png">
#
# ##### Now open the Db2 console, open the LOAD tool, Select / Drag the .CSV file for the first dataset, Next create a New Table, and then follow the steps on-screen instructions to load the data. Name the new tables as follows:
#
# 1.  **CENSUS_DATA**
# 2.  **CHICAGO_PUBLIC_SCHOOLS**
# 3.  **CHICAGO_CRIME_DATA**

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
# %load_ext sql

# %% [markdown]
# In the next cell enter your db2 connection string. Recall you created Service Credentials for your Db2 instance in first lab in Week 3. From the **uri** field of your Db2 service credentials copy everything after db2:// (except the double quote at the end) and paste it in the cell below after ibm_db_sa://
#
# <img src ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_edX/images/URI.jpg">

# %%
# Remember the connection string is of the format:
# %sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name
# Enter the connection string for your Db2 on Cloud database instance below
# %sql ibm_db_sa://fsh75730:Sajad@123456789@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Out:
# 'Connected: fsh75730@BLUDB'

# %% [markdown]
# ## Problems
#
# Now write and execute SQL queries to solve assignment problems
#
# ### Problem 1
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(*) AS "Number of crimes" FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ### Problem 2
#
# ##### List community areas with per capita income less than 11000.

# %%
# %sql SELECT community_area_name,per_capita_income \
FROM CENSUS_DATA \
WHERE per_capita_income < 11000\
ORDER BY per_capita_income;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', 8201),
#  ('South Lawndale', 10402),
#  ('Fuller Park', 10432),
#  ('West Garfield Park', 10934)]

# %% [markdown]
# ### Problem 3
#
# ##### List all case numbers for crimes  involving minors?

# %%
# %sql SELECT case_number, primary_type, description \
FROM CHICAGO_CRIME_DATA \
WHERE LCASE(description) like '%minor%';
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('HL266884', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR')]

# %% [markdown]
# ### Problem 4
#
# ##### List all kidnapping crimes involving a child?

# %%
# %sql SELECT primary_type, description FROM CHICAGO_CRIME_DATA \
WHERE LCASE(primary_type) = 'kidnapping' AND \
LCASE(description) LIKE '%child%';
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# ### Problem 5
#
# ##### What kinds of crimes were recorded at schools?

# %%
# %sql SELECT primary_type, description, location_description \
FROM CHICAGO_CRIME_DATA \
WHERE LCASE(location_description) LIKE '%school%';
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'PRO EMP HANDS NO/MIN INJURY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL DAMAGE', 'TO VEHICLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'POSS: HEROIN(WHITE)', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'MANU/DEL:CANNABIS 10GM OR LESS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'PRO EMP HANDS NO/MIN INJURY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'TO LAND', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT', 'SCHOOL, PUBLIC, BUILDING')]

# %% [markdown]
# ### Problem 6
#
# ##### List the average safety score for all types of schools.

# %%
# %sql SELECT "Elementary, Middle, or High School" as school_type, \
AVG(safety_score) as avg_safety_score \
FROM CHICAGO_PUBLIC_SCHOOLS \
GROUP BY "Elementary, Middle, or High School";
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('ES', Decimal('49.520383')),
#  ('HS', Decimal('49.623529')),
#  ('MS', Decimal('48.000000'))]

# %% [markdown]
# ### Problem 7
#
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql select COMMUNITY_AREA_NAME,PERCENT_HOUSEHOLDS_BELOW_POVERTY \
 from CENSUS_DATA \
order by PERCENT_HOUSEHOLDS_BELOW_POVERTY desc limit 5;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ### Problem 8
#
# ##### Which community area is most crime prone?

# %%
# %sql SELECT community_area_number,COUNT(*) AS CRIMES\
FROM CHICAGO_CRIME_DATA \
GROUP BY community_area_number\
ORDER BY CRIMES DESC LIMIT 10;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(25, Decimal('43')),
#  (None, Decimal('43')),
#  (23, Decimal('22')),
#  (68, Decimal('21')),
#  (28, Decimal('16')),
#  (29, Decimal('16')),
#  (8, Decimal('15')),
#  (71, Decimal('14')),
#  (24, Decimal('13')),
#  (66, Decimal('12'))]

# %%
# %sql SELECT community_area_name\
FROM CENSUS_DATA\
WHERE community_area_number IN \
(SELECT community_area_number FROM \
(SELECT community_area_number,COUNT(*) AS CRIMES\
FROM CHICAGO_CRIME_DATA \
GROUP BY community_area_number\
ORDER BY CRIMES DESC LIMIT 10));
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Near North Side',),
#  ('Humboldt park',),
#  ('West Town',),
#  ('Austin',),
#  ('Near West Side',),
#  ('North Lawndale',),
#  ('Chicago Lawn',),
#  ('Englewood',),
#  ('Auburn Gresham',)]

# %% [markdown]
# Double-click **here** for a hint
#
# <!--
# Query for the 'community area number' that is most crime prone.
# -->

# %% [markdown]
# ### Problem 9
#
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql SELECT community_area_name, hardship_index \
FROM CENSUS_DATA \
WHERE hardship_index = \
(SELECT MAX(hardship_index) FROM CENSUS_DATA);
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', 98)]

# %% [markdown]
# ### Problem 10
#
# ##### Use a sub-query to determine the Community Area Name with most number of crimes?

# %%
# %sql SELECT community_area_name, COUNT(*) AS CRIMES FROM\
(SELECT CD.community_area_name,CC.community_area_number\
FROM CENSUS_DATA CD, CHICAGO_CRIME_DATA CC \
WHERE CC.community_area_number = CD.community_area_number)\
GROUP BY community_area_name \
ORDER BY crimes DESC LIMIT 1;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Austin', Decimal('43'))]

# %%
# %%sql
# SELECT * FROM(
# SELECT community_area_number, COUNT(*) AS crimes FROM CHICAGO_CRIME_DATA
# GROUP BY community_area_number)
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(1, Decimal('6')),
#  (2, Decimal('7')),
#  (3, Decimal('4')),
#  (4, Decimal('3')),
#  (5, Decimal('4')),
#  (6, Decimal('11')),
#  (7, Decimal('5')),
#  (8, Decimal('15')),
#  (10, Decimal('3')),
#  (11, Decimal('2')),
#  (12, Decimal('1')),
#  (14, Decimal('5')),
#  (15, Decimal('5')),
#  (16, Decimal('8')),
#  (17, Decimal('3')),
#  (18, Decimal('2')),
#  (19, Decimal('8')),
#  (20, Decimal('3')),
#  (21, Decimal('6')),
#  (22, Decimal('9')),
#  (23, Decimal('22')),
#  (24, Decimal('13')),
#  (25, Decimal('43')),
#  (26, Decimal('10')),
#  (27, Decimal('8')),
#  (28, Decimal('16')),
#  (29, Decimal('16')),
#  (30, Decimal('8')),
#  (31, Decimal('9')),
#  (32, Decimal('7')),
#  (33, Decimal('1')),
#  (35, Decimal('5')),
#  (37, Decimal('2')),
#  (38, Decimal('8')),
#  (39, Decimal('4')),
#  (41, Decimal('2')),
#  (42, Decimal('8')),
#  (43, Decimal('9')),
#  (44, Decimal('8')),
#  (45, Decimal('4')),
#  (46, Decimal('9')),
#  (47, Decimal('1')),
#  (48, Decimal('5')),
#  (49, Decimal('11')),
#  (50, Decimal('3')),
#  (51, Decimal('4')),
#  (52, Decimal('2')),
#  (53, Decimal('6')),
#  (54, Decimal('2')),
#  (55, Decimal('1')),
#  (56, Decimal('2')),
#  (58, Decimal('10')),
#  (59, Decimal('2')),
#  (60, Decimal('1')),
#  (61, Decimal('10')),
#  (62, Decimal('4')),
#  (63, Decimal('7')),
#  (64, Decimal('2')),
#  (65, Decimal('3')),
#  (66, Decimal('12')),
#  (67, Decimal('12')),
#  (68, Decimal('21')),
#  (69, Decimal('11')),
#  (70, Decimal('8')),
#  (71, Decimal('14')),
#  (72, Decimal('4')),
#  (73, Decimal('3')),
#  (75, Decimal('1')),
#  (76, Decimal('4')),
#  (77, Decimal('2')),
#  (None, Decimal('43'))]

# %%
# %%sql
# SELECT * FROM(
# SELECT community_area_number, COUNT(*) AS schools FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY community_area_number)
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(1, Decimal('6')),
#  (2, Decimal('9')),
#  (3, Decimal('7')),
#  (4, Decimal('5')),
#  (5, Decimal('7')),
#  (6, Decimal('11')),
#  (7, Decimal('7')),
#  (8, Decimal('7')),
#  (9, Decimal('2')),
#  (10, Decimal('8')),
#  (11, Decimal('2')),
#  (12, Decimal('3')),
#  (13, Decimal('5')),
#  (14, Decimal('8')),
#  (15, Decimal('7')),
#  (16, Decimal('9')),
#  (17, Decimal('6')),
#  (18, Decimal('1')),
#  (19, Decimal('12')),
#  (20, Decimal('4')),
#  (21, Decimal('4')),
#  (22, Decimal('11')),
#  (23, Decimal('13')),
#  (24, Decimal('20')),
#  (25, Decimal('23')),
#  (26, Decimal('8')),
#  (27, Decimal('13')),
#  (28, Decimal('16')),
#  (29, Decimal('16')),
#  (30, Decimal('22')),
#  (31, Decimal('11')),
#  (32, Decimal('1')),
#  (33, Decimal('3')),
#  (34, Decimal('3')),
#  (35, Decimal('11')),
#  (36, Decimal('1')),
#  (37, Decimal('2')),
#  (38, Decimal('8')),
#  (39, Decimal('7')),
#  (40, Decimal('5')),
#  (41, Decimal('4')),
#  (42, Decimal('8')),
#  (43, Decimal('9')),
#  (44, Decimal('9')),
#  (45, Decimal('3')),
#  (46, Decimal('7')),
#  (47, Decimal('1')),
#  (48, Decimal('6')),
#  (49, Decimal('13')),
#  (50, Decimal('5')),
#  (51, Decimal('4')),
#  (52, Decimal('5')),
#  (53, Decimal('10')),
#  (54, Decimal('4')),
#  (55, Decimal('2')),
#  (56, Decimal('5')),
#  (57, Decimal('2')),
#  (58, Decimal('8')),
#  (59, Decimal('4')),
#  (60, Decimal('5')),
#  (61, Decimal('13')),
#  (62, Decimal('3')),
#  (63, Decimal('10')),
#  (64, Decimal('4')),
#  (65, Decimal('4')),
#  (66, Decimal('7')),
#  (67, Decimal('13')),
#  (68, Decimal('17')),
#  (69, Decimal('10')),
#  (70, Decimal('8')),
#  (71, Decimal('10')),
#  (72, Decimal('4')),
#  (73, Decimal('9')),
#  (74, Decimal('4')),
#  (75, Decimal('5')),
#  (76, Decimal('1')),
#  (77, Decimal('6'))]

# %%
# %%sql
# SELECT community_area_name,COUNT(*) AS CRIMES
# FROM (CENSUS_DATA CD LEFT JOIN CHICAGO_CRIME_DATA CC
# ON CD.community_area_number = CC.community_area_number)
# GROUP BY community_area_name ORDER BY CRIMES DESC;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Austin', Decimal('43')),
#  ('Humboldt park', Decimal('22')),
#  ('Englewood', Decimal('21')),
#  ('Near West Side', Decimal('16')),
#  ('North Lawndale', Decimal('16')),
#  ('Near North Side', Decimal('15')),
#  ('Auburn Gresham', Decimal('14')),
#  ('West Town', Decimal('13')),
#  ('Chicago Lawn', Decimal('12')),
#  ('West Englewood', Decimal('12')),
#  ('Greater Grand Crossing', Decimal('11')),
#  ('Lake View', Decimal('11')),
#  ('Roseland', Decimal('11')),
#  ('Brighton Park', Decimal('10')),
#  ('New City', Decimal('10')),
#  ('West Garfield Park', Decimal('10')),
#  ('Logan Square', Decimal('9')),
#  ('Lower West Side', Decimal('9')),
#  ('South Chicago', Decimal('9')),
#  ('South Shore', Decimal('9')),
#  ('Ashburn', Decimal('8')),
#  ('Belmont Cragin', Decimal('8')),
#  ('Chatham', Decimal('8')),
#  ('East Garfield Park', Decimal('8')),
#  ('Grand Boulevard', Decimal('8')),
#  ('Irving Park', Decimal('8')),
#  ('South Lawndale', Decimal('8')),
#  ('Woodlawn', Decimal('8')),
#  ('Gage Park', Decimal('7')),
#  ('Loop', Decimal('7')),
#  ('West Ridge', Decimal('7')),
#  ('Avondale', Decimal('6')),
#  ('Rogers Park', Decimal('6')),
#  ('West Pullman', Decimal('6')),
#  ('Albany Park', Decimal('5')),
#  ('Calumet Heights', Decimal('5')),
#  ('Douglas', Decimal('5')),
#  ('Lincoln Park', Decimal('5')),
#  ('Portage Park', Decimal('5')),
#  ('Avalon Park', Decimal('4')),
#  ('Beverly', Decimal('4')),
#  ('Kenwood', Decimal('4')),
#  ('North Center', Decimal('4')),
#  ("O'Hare", Decimal('4')),
#  ('South Deering', Decimal('4')),
#  ('Uptown', Decimal('4')),
#  ('West Elsdon', Decimal('4')),
#  ('Dunning', Decimal('3')),
#  ('Hermosa', Decimal('3')),
#  ('Lincoln Square', Decimal('3')),
#  ('Norwood Park', Decimal('3')),
#  ('Pullman', Decimal('3')),
#  ('Washington Height', Decimal('3')),
#  ('West Lawn', Decimal('3')),
#  ('Clearing', Decimal('2')),
#  ('East Side', Decimal('2')),
#  ('Edgewater', Decimal('2')),
#  ('Fuller Park', Decimal('2')),
#  ('Garfield Ridge', Decimal('2')),
#  ('Hyde Park', Decimal('2')),
#  ('Jefferson Park', Decimal('2')),
#  ('McKinley Park', Decimal('2')),
#  ('Montclaire', Decimal('2')),
#  ('Riverdale', Decimal('2')),
#  ('Archer Heights', Decimal('1')),
#  ('Armour Square', Decimal('1')),
#  ('Bridgeport', Decimal('1')),
#  ('Burnside', Decimal('1')),
#  ('CHICAGO', Decimal('1')),
#  ('Edison Park', Decimal('1')),
#  ('Forest Glen', Decimal('1')),
#  ('Hegewisch', Decimal('1')),
#  ('Morgan Park', Decimal('1')),
#  ('Mount Greenwood', Decimal('1')),
#  ('Near South Side', Decimal('1')),
#  ('North Park', Decimal('1')),
#  ('Oakland', Decimal('1')),
#  ('Washington Park', Decimal('1'))]

# %%
# %%sql
# SELECT CD.community_area_name,COUNT(*) AS SCHOOLS
# FROM (CENSUS_DATA CD LEFT JOIN CHICAGO_PUBLIC_SCHOOLS CS
# ON CD.community_area_number = CS.community_area_number)
# GROUP BY CD.community_area_name ORDER BY SCHOOLS DESC;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Austin', Decimal('23')),
#  ('South Lawndale', Decimal('22')),
#  ('West Town', Decimal('20')),
#  ('Englewood', Decimal('17')),
#  ('Near West Side', Decimal('16')),
#  ('North Lawndale', Decimal('16')),
#  ('East Garfield Park', Decimal('13')),
#  ('Humboldt park', Decimal('13')),
#  ('New City', Decimal('13')),
#  ('Roseland', Decimal('13')),
#  ('West Englewood', Decimal('13')),
#  ('Belmont Cragin', Decimal('12')),
#  ('Douglas', Decimal('11')),
#  ('Lake View', Decimal('11')),
#  ('Logan Square', Decimal('11')),
#  ('Lower West Side', Decimal('11')),
#  ('Auburn Gresham', Decimal('10')),
#  ('Gage Park', Decimal('10')),
#  ('Greater Grand Crossing', Decimal('10')),
#  ('West Pullman', Decimal('10')),
#  ('Chatham', Decimal('9')),
#  ('Irving Park', Decimal('9')),
#  ('South Shore', Decimal('9')),
#  ('Washington Height', Decimal('9')),
#  ('West Ridge', Decimal('9')),
#  ('Albany Park', Decimal('8')),
#  ('Ashburn', Decimal('8')),
#  ('Brighton Park', Decimal('8')),
#  ('Grand Boulevard', Decimal('8')),
#  ('Norwood Park', Decimal('8')),
#  ('West Garfield Park', Decimal('8')),
#  ('Woodlawn', Decimal('8')),
#  ('Chicago Lawn', Decimal('7')),
#  ('Kenwood', Decimal('7')),
#  ('Lincoln Park', Decimal('7')),
#  ('Near North Side', Decimal('7')),
#  ('North Center', Decimal('7')),
#  ('Portage Park', Decimal('7')),
#  ('South Chicago', Decimal('7')),
#  ('Uptown', Decimal('7')),
#  ('Calumet Heights', Decimal('6')),
#  ('Dunning', Decimal('6')),
#  ('Edgewater', Decimal('6')),
#  ('Rogers Park', Decimal('6')),
#  ('Bridgeport', Decimal('5')),
#  ('East Side', Decimal('5')),
#  ('Garfield Ridge', Decimal('5')),
#  ('Lincoln Square', Decimal('5')),
#  ('Morgan Park', Decimal('5')),
#  ('North Park', Decimal('5')),
#  ('Pullman', Decimal('5')),
#  ('Washington Park', Decimal('5')),
#  ('Avondale', Decimal('4')),
#  ('Beverly', Decimal('4')),
#  ('Clearing', Decimal('4')),
#  ('Hermosa', Decimal('4')),
#  ('Hyde Park', Decimal('4')),
#  ('McKinley Park', Decimal('4')),
#  ('Mount Greenwood', Decimal('4')),
#  ('Riverdale', Decimal('4')),
#  ('South Deering', Decimal('4')),
#  ('West Lawn', Decimal('4')),
#  ('Armour Square', Decimal('3')),
#  ('Avalon Park', Decimal('3')),
#  ('Forest Glen', Decimal('3')),
#  ('Near South Side', Decimal('3')),
#  ('West Elsdon', Decimal('3')),
#  ('Archer Heights', Decimal('2')),
#  ('Edison Park', Decimal('2')),
#  ('Fuller Park', Decimal('2')),
#  ('Hegewisch', Decimal('2')),
#  ('Jefferson Park', Decimal('2')),
#  ('Burnside', Decimal('1')),
#  ('CHICAGO', Decimal('1')),
#  ('Loop', Decimal('1')),
#  ('Montclaire', Decimal('1')),
#  ("O'Hare", Decimal('1')),
#  ('Oakland', Decimal('1'))]

# %%
# %sql SELECT DISTINCT(community_area_name) FROM CHICAGO_PUBLIC_SCHOOLS\
WHERE community_area_number IN \
(SELECT community_area_number FROM \
(SELECT community_area_number, COUNT(*) AS CRIMES\
FROM CHICAGO_CRIME_DATA \
GROUP BY community_area_number\
ORDER BY CRIMES DESC LIMIT 1));
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('AUSTIN',)]

# %%
# %%sql
# SELECT community_area_name
# FROM CENSUS_DATA CD where CD.community_area_number = ANY
# (SELECT CC.community_area_number FROM(
# SELECT community_area_number, COUNT(*) AS crimes FROM CHICAGO_CRIME_DATA
# GROUP BY community_area_number) CC ) AND
# CD.community_area_number = ANY
# (SELECT CS.community_area_number FROM(
# SELECT community_area_number, COUNT(*) AS schools FROM CHICAGO_PUBLIC_SCHOOLS
# GROUP BY community_area_number) CS);
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [('Rogers Park',),
#  ('West Ridge',),
#  ('Uptown',),
#  ('Lincoln Square',),
#  ('North Center',),
#  ('Lake View',),
#  ('Lincoln Park',),
#  ('Near North Side',),
#  ('Norwood Park',),
#  ('Jefferson Park',),
#  ('Forest Glen',),
#  ('Albany Park',),
#  ('Portage Park',),
#  ('Irving Park',),
#  ('Dunning',),
#  ('Montclaire',),
#  ('Belmont Cragin',),
#  ('Hermosa',),
#  ('Avondale',),
#  ('Logan Square',),
#  ('Humboldt park',),
#  ('West Town',),
#  ('Austin',),
#  ('West Garfield Park',),
#  ('East Garfield Park',),
#  ('Near West Side',),
#  ('North Lawndale',),
#  ('South Lawndale',),
#  ('Lower West Side',),
#  ('Loop',),
#  ('Near South Side',),
#  ('Douglas',),
#  ('Fuller Park',),
#  ('Grand Boulevard',),
#  ('Kenwood',),
#  ('Hyde Park',),
#  ('Woodlawn',),
#  ('South Shore',),
#  ('Chatham',),
#  ('Avalon Park',),
#  ('South Chicago',),
#  ('Burnside',),
#  ('Calumet Heights',),
#  ('Roseland',),
#  ('Pullman',),
#  ('South Deering',),
#  ('East Side',),
#  ('West Pullman',),
#  ('Riverdale',),
#  ('Hegewisch',),
#  ('Garfield Ridge',),
#  ('Brighton Park',),
#  ('McKinley Park',),
#  ('Bridgeport',),
#  ('New City',),
#  ('West Elsdon',),
#  ('Gage Park',),
#  ('Clearing',),
#  ('West Lawn',),
#  ('Chicago Lawn',),
#  ('West Englewood',),
#  ('Englewood',),
#  ('Greater Grand Crossing',),
#  ('Ashburn',),
#  ('Auburn Gresham',),
#  ('Beverly',),
#  ('Washington Height',),
#  ('Morgan Park',),
#  ("O'Hare",),
#  ('Edgewater',)]

# %%
# %sql SELECT CD.community_area_number,\
CD.PER_CAPITA_INCOME, CS.COMMUNITY_AREA_NAME \
FROM ((CENSUS_DATA CD INNER JOIN CHICAGO_CRIME_DATA CC \
ON CD.community_area_number = CC.community_area_number)\
INNER JOIN CHICAGO_PUBLIC_SCHOOLS CS ON \
CD.community_area_number = CS.community_area_number)\
G;
# Out:
#  * ibm_db_sa://fsh75730:***@dashdb-txn-sbox-yp-lon02-07.services.eu-gb.bluemix.net:50000/BLUDB
# Done.
# [(2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (7, 71551, 'LINCOLN PARK'),
#  (7, 71551, 'LINCOLN PARK'),
#  (7, 71551, 'LINCOLN PARK'),
#  (7, 71551, 'LINCOLN PARK'),
#  (7, 71551, 'LINCOLN PARK'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (43, 19398, 'SOUTH SHORE'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (14, 21323, 'ALBANY PARK'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (5, 57123, 'NORTH CENTER'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (72, 39523, 'BEVERLY'),
#  (72, 39523, 'BEVERLY'),
#  (72, 39523, 'BEVERLY'),
#  (72, 39523, 'BEVERLY'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (27, 12961, 'EAST GARFIELD PARK'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (48, 28887, 'CALUMET HEIGHTS'),
#  (48, 28887, 'CALUMET HEIGHTS'),
#  (48, 28887, 'CALUMET HEIGHTS'),
#  (48, 28887, 'CALUMET HEIGHTS'),
#  (48, 28887, 'CALUMET HEIGHTS'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (28, 44689, 'NEAR WEST SIDE'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (46, 16579, 'SOUTH CHICAGO'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (6, 60058, 'LAKE VIEW'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (42, 18672, 'WOODLAWN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (25, 15957, 'AUSTIN'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (75, 27149, 'MORGAN PARK'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (31, 16444, 'LOWER WEST SIDE'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (39, 35911, 'KENWOOD'),
#  (64, 25113, 'CLEARING'),
#  (64, 25113, 'CLEARING'),
#  (41, 39056, 'HYDE PARK'),
#  (41, 39056, 'HYDE PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (51, 14685, 'SOUTH DEERING'),
#  (51, 14685, 'SOUTH DEERING'),
#  (51, 14685, 'SOUTH DEERING'),
#  (51, 14685, 'SOUTH DEERING'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (44, 18881, 'CHATHAM'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (16, 27249, 'IRVING PARK'),
#  (21, 20039, 'AVONDALE'),
#  (21, 20039, 'AVONDALE'),
#  (21, 20039, 'AVONDALE'),
#  (21, 20039, 'AVONDALE'),
#  (21, 20039, 'AVONDALE'),
#  (21, 20039, 'AVONDALE'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (61, 12765, 'NEW CITY'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (70, 23482, 'ASHBURN'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (73, 19713, 'WASHINGTON HEIGHTS'),
#  (73, 19713, 'WASHINGTON HEIGHTS'),
#  (73, 19713, 'WASHINGTON HEIGHTS'),
#  (41, 39056, 'HYDE PARK'),
#  (41, 39056, 'HYDE PARK'),
#  (60, 22694, 'BRIDGEPORT'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (19, 15461, 'BELMONT CRAGIN'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (22, 31908, 'LOGAN SQUARE'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (69, 17285, 'GREATER GRAND CROSSING'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (67, 11317, 'WEST ENGLEWOOD'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (17, 26282, 'DUNNING'),
#  (35, 23791, 'DOUGLAS'),
#  (35, 23791, 'DOUGLAS'),
#  (35, 23791, 'DOUGLAS'),
#  (35, 23791, 'DOUGLAS'),
#  (35, 23791, 'DOUGLAS'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (45, 24454, 'AVALON PARK'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (24, 43198, 'WEST TOWN'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (71, 15528, 'AUBURN GRESHAM'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (66, 13231, 'CHICAGO LAWN'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (58, 13089, 'BRIGHTON PARK'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (49, 17949, 'ROSELAND'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (29, 12034, 'NORTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (2, 23040, 'WEST RIDGE'),
#  (10, 32875, 'NORWOOD PARK'),
#  (10, 32875, 'NORWOOD PARK'),
#  (10, 32875, 'NORWOOD PARK'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (38, 23472, 'GRAND BOULEVARD'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (30, 10402, 'SOUTH LAWNDALE'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (23, 13781, 'HUMBOLDT PARK'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (68, 11888, 'ENGLEWOOD'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  (26, 10934, 'WEST GARFIELD PARK'),
#  ...]

# %% [markdown]
# Copyright © 2020 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license?cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork-20127838&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).

# %% [markdown]
# ## Author(s)
#
# <h4> Hima Vasudevan </h4>
# <h4> Rav Ahuja </h4>
# <h4> Ramesh Sannreddy </h4>
#
# ## Contribtuor(s)
#
# <h4> Malika Singla </h4>
#
# ## Change log
#
# | Date       | Version | Changed by        | Change Description                             |
# | ---------- | ------- | ----------------- | ---------------------------------------------- |
# | 2020-01-15 | 2.2     | Rav Ahuja         | Removed problem 11 and fixed changelog         |
# | 2020-11-25 | 2.1     | Ramesh Sannareddy | Updated the problem statements, and datasets   |
# | 2020-09-05 | 2.0     | Malika Singla     | Moved lab to course repo in GitLab             |
# | 2018-07-18 | 1.0     | Rav Ahuja         | Several updates including loading instructions |
# | 2018-05-04 | 0.1     | Hima Vasudevan    | Created initial version                        |
#
# ## <h3 align="center"> © IBM Corporation 2020. All rights reserved. <h3/>
